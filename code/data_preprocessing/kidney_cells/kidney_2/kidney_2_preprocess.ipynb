# %% [markdown]
# # ScRNA-Seq of human kidney

# %% [markdown]
# <br>Data from [Muto, Y. et al.](https://pubmed.ncbi.nlm.nih.gov/33850129/)
# <br>Data: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM4572193

# %%
# Import packages
import scanpy as sc
import pandas as pd
from functions import data_preprocessing as dp

# %%
# Path of data
file = '../../../../data/raw/kidney_cells/GSM4572193_Control2_filtered_feature_bc_matrix.h5'

# Read data
adata = sc.read_10x_h5(filename=file)

adata.var_names_make_unique()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\MScEnv\lib\site-packages\anndata\_core\anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# c:\Users\user\Documents\GitHub\Masters_Thesis\MScEnv\lib\site-packages\anndata\_core\anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# c:\Users\user\Documents\GitHub\Masters_Thesis\MScEnv\lib\site-packages\anndata\_core\anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
print(adata.X.shape)
print(adata)
# Out:
# (4245, 33538)
# AnnData object with n_obs × n_vars = 4245 × 33538
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
adata.var.head()
# Out:
#                     gene_ids    feature_types                genome
# MIR1302-2HG  ENSG00000243485  Gene Expression  GRCh38-1.2.0_premrna
# FAM138A      ENSG00000237613  Gene Expression  GRCh38-1.2.0_premrna
# OR4F5        ENSG00000186092  Gene Expression  GRCh38-1.2.0_premrna
# AL627309.1   ENSG00000238009  Gene Expression  GRCh38-1.2.0_premrna
# AL627309.3   ENSG00000239945  Gene Expression  GRCh38-1.2.0_premrna

# %%
adata.X = adata.X.toarray()

# %% [markdown]
# ## Preprocessing

# %%
# Add QC metrics to adata
adata = dp.QC().QC_metric_calc(adata)
print(adata.obs)
# Out:
#                     n_counts  log_n_counts  n_genes  log_n_genes  \
# AAACCTGAGCCCTAAT-1    1349.0      7.207860     1008     6.916715
# AAACCTGAGGCTATCT-1     567.0      6.342122      450     6.111467
# AAACCTGCAAAGGAAG-1    2195.0      7.694393     1285     7.159292
# AAACCTGCAGATGGGT-1     976.0      6.884487      639     6.461468
# AAACCTGGTTACCGAT-1     967.0      6.875232      707     6.562444
# ...                      ...           ...      ...          ...
# TTTGTCAGTAAATACG-1    4208.0      8.344980     2052     7.627057
# TTTGTCAGTACTTAGC-1     972.0      6.880384      714     6.572283
# TTTGTCATCAAGGTAA-1    1089.0      6.993933      773     6.651572
# TTTGTCATCATAACCG-1    1277.0      7.153052      837     6.731018
# TTTGTCATCTTTAGTC-1     520.0      6.255750      453     6.118097
#
#                     pct_counts_in_top_20_genes   mt_frac  ribo_frac  hem_frac
# AAACCTGAGCCCTAAT-1                    0.120830  0.004448   0.002224       0.0
# AAACCTGAGGCTATCT-1                    0.176367  0.003527   0.001764       0.0
# AAACCTGCAAAGGAAG-1                    0.220501  0.000456   0.000000       0.0
# AAACCTGCAGATGGGT-1                    0.228484  0.002049   0.001025       0.0
# AAACCTGGTTACCGAT-1                    0.171665  0.022751   0.004137       0.0
# ...                                        ...       ...        ...       ...
# TTTGTCAGTAAATACG-1                    0.146863  0.000475   0.001663       0.0
# TTTGTCAGTACTTAGC-1                    0.143004  0.001029   0.000000       0.0
# TTTGTCATCAAGGTAA-1                    0.136823  0.000000   0.000918       0.0
# TTTGTCATCATAACCG-1                    0.241190  0.009397   0.006265       0.0
# TTTGTCATCTTTAGTC-1                    0.142308  0.009615   0.001923       0.0
#
# [4245 rows x 8 columns]

# %%
qc_adata = dp.QC().QC_filter_outliers(adata,[5,5,5,8])
# Out:
# Number of cells before QC filtering: 4245
# Number of cells removed by log_n_genes filtering: 5
# Number of cells removed by log_n_counts filtering: 5
# Number of cells removed by pct_counts_in_top_20_genes filtering: 104
# Number of cells removed by mt_frac filtering: 330
# Number of cells post QC filtering: 3889
# Number of genes before filtering: 33538
# Number of genes after filtering so theres min 20 unique cells per gene: 13889

# %%
dp.EDA().ViolinJitter([adata, qc_adata], 
                        y_rows=['n_counts','log_n_counts','n_genes','log_n_genes','mt_frac','pct_counts_in_top_20_genes','ribo_frac','hem_frac'], 
                        title="Violin Plots",
                        subtitle=["Unfiltered", "QC Filtered"])

# %%
dp.EDA().ScatterForQCMetrics([adata, qc_adata],
                            title="Scatter Plot",
                            subtitle=["Unfiltered", "QC Filtered"])

# %% [markdown]
# ## Normalize

# %%
norm_qc_adata = dp.log1p_normalize(qc_adata)

# %%
norm_qc_adata
# Out:
# AnnData object with n_obs × n_vars = 3889 × 13889
#     obs: 'n_counts', 'log_n_counts', 'n_genes', 'log_n_genes', 'pct_counts_in_top_20_genes', 'mt_frac', 'ribo_frac', 'hem_frac', 'outlier', 'size_factors'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells'
#     layers: 'pp_counts', 'log1p_counts'

# %%
# Visualize counts before and after normalization
dp.EDA().VisualizeNormalization(norm_qc_adata)

# %%
# Download normalized count matrix
sc.pp.highly_variable_genes(norm_qc_adata, n_top_genes=4000, flavor="cell_ranger")
HVG_data = norm_qc_adata[:, norm_qc_adata.var["highly_variable"]]
normalized_counts = pd.DataFrame(HVG_data.layers["log1p_counts"])
normalized_counts.index = HVG_data.obs.index.to_list()
normalized_counts.columns = HVG_data.var.index.to_list()
normalized_counts.to_csv("kidney_2.csv")
norm_qc_adata.write("kidney_2_adata.h5ad")
