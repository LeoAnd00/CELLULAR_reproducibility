# %% [markdown]
# ### Calculate accuracy, balanced accuracy, and F1 score for all datsets, folds, and all methods/models

# %%
# Import packages
from calc_metrics import metrics as metrics

# %%
metric_env = metrics()

# %% [markdown]
# ### Segerstolpe

# %%
data_name = "Segerstolpe"
metric_env.calc_metrics(path=f"{data_name}/results/scNym_hvgs_output", method_name="scNym_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scibet_hvgs_output", method_name="SciBet_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/seurat_hvgs_output", method_name="Seurat_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_cell_hvgs_output", method_name="CellID_cell_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_group_hvgs_output", method_name="CellID_group_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scNym_output", method_name="scNym", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scibet_output", method_name="SciBet", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/seurat_output", method_name="Seurat", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_cell_output", method_name="CellID_cell", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_group_output", method_name="CellID_group", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/TOSICA_output", method_name="TOSICA", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CELLULAR_output", method_name="CELLULAR", dataset_name=data_name)
# Out:
# Method scNym_HVGs | Fold 1
# Accuracy: 0.9118065433854907
# Balanced Accuracy: 0.662506007551448
# F1 Score: 0.903460523180928
# Method scNym_HVGs | Fold 2
# Accuracy: 0.8933143669985776
# Balanced Accuracy: 0.6570261411331796
# F1 Score: 0.8857637850507433
# Method scNym_HVGs | Fold 3
# Accuracy: 0.9075391180654339
# Balanced Accuracy: 0.5865675480975882
# F1 Score: 0.8984853936778606
# Method scNym_HVGs | Fold 4
# Accuracy: 0.9132290184921764
# Balanced Accuracy: 0.5474802262840447
# F1 Score: 0.9003529140455875
# Method scNym_HVGs | Fold 5
# Accuracy: 0.915954415954416
# Balanced Accuracy: 0.643000135036721
# F1 Score: 0.9057185998986604
# Method SciBet_HVGs | Fold 1
# Accuracy: 0.7425320056899004
# Balanced Accuracy: 0.8745241802692949
# F1 Score: 0.740193529415541
# Method SciBet_HVGs | Fold 2
# Accuracy: 0.7695590327169275
# Balanced Accuracy: 0.9022969178579933
# F1 Score: 0.7723400029918902
# Method SciBet_HVGs | Fold 3
# Accuracy: 0.7624466571834992
# ...

# %% [markdown]
# ### MacParland

# %%
data_name = "MacParland"
metric_env.calc_metrics(path=f"{data_name}/results/scNym_hvgs_output", method_name="scNym_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scibet_hvgs_output", method_name="SciBet_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/seurat_hvgs_output", method_name="Seurat_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_cell_hvgs_output", method_name="CellID_cell_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_group_hvgs_output", method_name="CellID_group_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scNym_output", method_name="scNym", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scibet_output", method_name="SciBet", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/seurat_output", method_name="Seurat", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_cell_output", method_name="CellID_cell", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_group_output", method_name="CellID_group", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/TOSICA_output", method_name="TOSICA", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CELLULAR_output", method_name="CELLULAR", dataset_name=data_name)
# Out:
# Method scNym_HVGs | Fold 1
# Accuracy: 0.9431616341030196
# Balanced Accuracy: 0.9558969348452659
# F1 Score: 0.9430515668771844
# Method scNym_HVGs | Fold 2
# Accuracy: 0.9526346950858496
# Balanced Accuracy: 0.9685209645440225
# F1 Score: 0.9525865776208958
# Method scNym_HVGs | Fold 3
# Accuracy: 0.9425695677915926
# Balanced Accuracy: 0.9340515307265609
# F1 Score: 0.9426544961587088
# Method scNym_HVGs | Fold 4
# Accuracy: 0.9561870929544108
# Balanced Accuracy: 0.958418308947983
# F1 Score: 0.955943556551195
# Method scNym_HVGs | Fold 5
# Accuracy: 0.9377962085308057
# Balanced Accuracy: 0.9385085812318474
# F1 Score: 0.9377473516022652
# Method SciBet_HVGs | Fold 1
# Accuracy: 0.9319123741859088
# Balanced Accuracy: 0.9493148021614927
# F1 Score: 0.9317684053057356
# Method SciBet_HVGs | Fold 2
# Accuracy: 0.9348727057430433
# Balanced Accuracy: 0.9466778318409368
# F1 Score: 0.9346865516369641
# Method SciBet_HVGs | Fold 3
# Accuracy: 0.9212551805802249
# ...

# %% [markdown]
# ### Baron

# %%
data_name = "Baron"
metric_env.calc_metrics(path=f"{data_name}/results/scNym_hvgs_output", method_name="scNym_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scibet_hvgs_output", method_name="SciBet_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/seurat_hvgs_output", method_name="Seurat_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_cell_hvgs_output", method_name="CellID_cell_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_group_hvgs_output", method_name="CellID_group_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scNym_output", method_name="scNym", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scibet_output", method_name="SciBet", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/seurat_output", method_name="Seurat", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_cell_output", method_name="CellID_cell", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_group_output", method_name="CellID_group", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/TOSICA_output", method_name="TOSICA", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CELLULAR_output", method_name="CELLULAR", dataset_name=data_name)
# Out:
# Method scNym_HVGs | Fold 1
# Accuracy: 0.9929988331388565
# Balanced Accuracy: 0.9876456921423405
# F1 Score: 0.9929786411502053
# Method scNym_HVGs | Fold 2
# Accuracy: 0.9918319719953326
# Balanced Accuracy: 0.9949904507818964
# F1 Score: 0.9918383401466622
# Method scNym_HVGs | Fold 3
# Accuracy: 0.9883313885647608
# Balanced Accuracy: 0.9516941098866069
# F1 Score: 0.9880925536834614
# Method scNym_HVGs | Fold 4
# Accuracy: 0.985414235705951
# Balanced Accuracy: 0.9708316125023199
# F1 Score: 0.9854740228617027
# Method scNym_HVGs | Fold 5
# Accuracy: 0.9889083479276124
# Balanced Accuracy: 0.8950462450048632
# F1 Score: 0.9886162825181491
# Method SciBet_HVGs | Fold 1
# Accuracy: 0.9795799299883314
# Balanced Accuracy: 0.9859135871385077
# F1 Score: 0.9796537432310704
# Method SciBet_HVGs | Fold 2
# Accuracy: 0.9789964994165694
# Balanced Accuracy: 0.9884397037422368
# F1 Score: 0.9794420463650623
# Method SciBet_HVGs | Fold 3
# Accuracy: 0.9766627771295215
# ...

# %%
data_name = "Zheng68k"
metric_env.calc_metrics(path=f"{data_name}/results/scNym_hvgs_output", method_name="scNym_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scibet_hvgs_output", method_name="SciBet_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/seurat_hvgs_output", method_name="Seurat_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_cell_hvgs_output", method_name="CellID_cell_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_group_hvgs_output", method_name="CellID_group_HVGs", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scNym_output", method_name="scNym", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/scibet_output", method_name="SciBet", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/seurat_output", method_name="Seurat", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_cell_output", method_name="CellID_cell", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CellID_group_output", method_name="CellID_group", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/TOSICA_output", method_name="TOSICA", dataset_name=data_name)
metric_env.calc_metrics(path=f"{data_name}/results/CELLULAR_output", method_name="CELLULAR", dataset_name=data_name)
# Out:
# Method scNym_HVGs | Fold 1
# Accuracy: 0.7673519976669583
# Balanced Accuracy: 0.6569425841048332
# F1 Score: 0.7634506201263767
# Method scNym_HVGs | Fold 2
# Accuracy: 0.7586759988334791
# Balanced Accuracy: 0.646117407686975
# F1 Score: 0.7516239316084455
# Method scNym_HVGs | Fold 3
# Accuracy: 0.7658209390492855
# Balanced Accuracy: 0.654321676758689
# F1 Score: 0.7609170152903287
# Method scNym_HVGs | Fold 4
# Accuracy: 0.7505103528725576
# Balanced Accuracy: 0.6541763448918374
# F1 Score: 0.7445656726285325
# Method scNym_HVGs | Fold 5
# Accuracy: 0.7804593510754648
# Balanced Accuracy: 0.6771535203079188
# F1 Score: 0.7788276571766537
# Method SciBet_HVGs | Fold 1
# Accuracy: 0.6942257217847769
# Balanced Accuracy: 0.6725080363183783
# F1 Score: 0.7127130607244638
# Method SciBet_HVGs | Fold 2
# Accuracy: 0.6905074365704287
# Balanced Accuracy: 0.7050118962614841
# F1 Score: 0.7065923208007195
# Method SciBet_HVGs | Fold 3
# Accuracy: 0.6923301254009916
# ...

# %% [markdown]
# ### Save results

# %%
metric_env.download_results(path="results_and_visualizations/results_benchmark")
