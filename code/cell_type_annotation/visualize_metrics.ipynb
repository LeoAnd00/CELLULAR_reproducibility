# %% [markdown]
# ### Make visualizations based on the accuracy, balanced accuracy, and F1 score of each method/model and on each dataset

# %%
# Import packages
from visualize_metrics import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %%
file = "results_and_visualizations/results_benchmark"
VisEnv.read_csv(file=file)

# %%
image_path = "figures/Annotation_metrics"
VisEnv.BoxPlotVisualization(image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_annotation\visualize_metrics.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "CELLULAR"] = "CELLULAR | HVGs"
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_annotation\visualize_metrics.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "TOSICA"] = "TOSICA | HVGs"
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_annotation\visualize_metrics.py:58: SettingWithCopyWarning:
# ...

# %% [markdown]
# ### Normalized average across datasets for each metric

# %% [markdown]
# Here we calculate the mean of each method/model and dataset. Then we normalize the mean metric scores for each dataset to make them comparable across datasets. This create 4 normalized data points for each method. This data points are used for making the box plot visualization.

# %% [markdown]
# The bar plot is created by calculating the mean metric score for each method/model and for each metric. Then we calculate the mean value across all metrics for each method/model. This gives 1 value per method/model and can be visualized in a bar plot.

# %%
image_path = "figures/Annotation_average_metrics"
VisEnv.BarPlotAverageMetricsVisualization(image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_annotation\visualize_metrics.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "CELLULAR"] = "CELLULAR | HVGs"
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_annotation\visualize_metrics.py:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "TOSICA"] = "TOSICA | HVGs"
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_annotation\visualize_metrics.py:182: SettingWithCopyWarning:
# ...
