# %% [markdown]
# ## scNym: https://github.com/calico/scnym

# %%
import scnym
from scnym.api import scnym_api
import torch
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import scanpy as sc
# Out:
# WARNING:tensorflow:From c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def split_data(data_path: str, 
               fold: int=1,
               folds: int=5,
               batch_key: str="patientID", 
               label_key: str="cell_type",
               seed: int=42,
               HVG: bool=True,
               HVGs: int=2000):
    
    adata = sc.read(data_path, cache=True)

    adata.obs["batch"] = adata.obs[batch_key]

    # Ensure reproducibility
    def rep_seed(seed):
        # Check if a GPU is available
        if torch.cuda.is_available():
            # Set the random seed for PyTorch CUDA (GPU) operations
            torch.cuda.manual_seed(seed)
            # Set the random seed for all CUDA devices (if multiple GPUs are available)
            torch.cuda.manual_seed_all(seed)
        
        # Set the random seed for CPU-based PyTorch operations
        torch.manual_seed(seed)
        
        # Set the random seed for NumPy
        np.random.seed(seed)
        
        # Set the random seed for Python's built-in 'random' module
        random.seed(seed)
        
        # Set the random seed for TensorFlow
        tf.random.set_seed(seed)
        
        # Set CuDNN to deterministic mode for PyTorch (GPU)
        torch.backends.cudnn.deterministic = True
        
        # Disable CuDNN's benchmarking mode for deterministic behavior
        torch.backends.cudnn.benchmark = False

    rep_seed(seed)

    # Initialize Stratified K-Fold
    stratified_kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)

    # Iterate through the folds
    adata_original = adata.copy()
    test_adata_original = adata.copy()
    fold_counter = 0
    for train_index, test_index in stratified_kfold.split(adata_original.X, adata_original.obs[label_key]):
        fold_counter += 1
        
        adata = adata_original[train_index, :].copy()
        test_adata = test_adata_original[test_index, :].copy()

        if HVG:
            sc.pp.highly_variable_genes(adata, n_top_genes=HVGs, flavor="cell_ranger")
            test_adata = test_adata[:, adata.var["highly_variable"]].copy()
            adata = adata[:, adata.var["highly_variable"]].copy()
        
        if fold_counter == fold:
            
            return adata, test_adata

# %%
data_path = "../../../data/processed/data_for_evaluating_cell_type_annotation/MacParland.h5ad"

# Iterate through folds
results = None
for fold_idx in range(5):
    fold = fold_idx + 1

    adata_train, adata_test = split_data(data_path=data_path, fold=fold)

    # Train model
    scnym_api(
        adata=adata_train,
        task='train',
        groupby='cell_type',
        out_path='./scnym_outputs',
        config='no_new_identity',
    )

    # Predict test data
    scnym_api(
        adata=adata_test,
        task='predict',
        key_added='scNym',
        config='no_new_identity',
        trained_model='./scnym_outputs'
    )

    # Save results in dataframe
    if fold == 1:
        results = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                "true_label": adata_test.obs["cell_type"].to_list(), 
                                "fold": [fold]*adata_test.obs['scNym'].shape[0]})
    else:   
        dataframe_temp = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                    "true_label": adata_test.obs["cell_type"].to_list(), 
                                    "fold": [fold]*adata_test.obs['scNym'].shape[0]})
        results = pd.concat([results,dataframe_temp], axis=0)

# Reset index
results.reset_index(drop=True, inplace=True)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (6755, 2000)
# y:  (6755,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.01205784734338522
# running_acc  :  0.03515625
# corrects: 9.000000 | total: 256.000000
# train Loss : 0.0060
# train Acc : 0.5814
# TRAIN EPOCH corrects: 3181.000000 | total: 5471.000000
# val Loss : 0.0036
# val Acc : 0.8586
# VAL EPOCH corrects: 522.000000 | total: 608.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.00307990494184196
# running_acc  :  0.796875
# corrects: 204.000000 | total: 256.000000
# train Loss : 0.0024
# train Acc : 0.8320
# TRAIN EPOCH corrects: 4552.000000 | total: 5471.000000
# val Loss : 0.0029
# val Acc : 0.8586
# VAL EPOCH corrects: 522.000000 | total: 608.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.001842114026658237
# running_acc  :  0.828125
# corrects: 212.000000 | total: 256.000000
# train Loss : 0.0016
# train Acc : 0.8978
# TRAIN EPOCH corrects: 4912.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.0011258686427026987
# running_acc  :  0.9296875
# corrects: 238.000000 | total: 256.000000
# train Loss : 0.0011
# train Acc : 0.9294
# TRAIN EPOCH corrects: 5085.000000 | total: 5471.000000
# val Loss : 0.0009
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.0009471778757870197
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# train Loss : 0.0009
# train Acc : 0.9402
# TRAIN EPOCH corrects: 5144.000000 | total: 5471.000000
# val Loss : 0.0022
# val Acc : 0.8980
# VAL EPOCH corrects: 546.000000 | total: 608.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0009595225565135479
# running_acc  :  0.91796875
# corrects: 235.000000 | total: 256.000000
# train Loss : 0.0008
# train Acc : 0.9470
# TRAIN EPOCH corrects: 5181.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0008
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.0006293453625403345
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9572
# TRAIN EPOCH corrects: 5237.000000 | total: 5471.000000
# val Loss : 0.0017
# val Acc : 0.9062
# VAL EPOCH corrects: 551.000000 | total: 608.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.0005588215426541865
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9600
# TRAIN EPOCH corrects: 5252.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9342
# VAL EPOCH corrects: 568.000000 | total: 608.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.0005177559796720743
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9634
# TRAIN EPOCH corrects: 5271.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.0005029932362958789
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9647
# TRAIN EPOCH corrects: 5278.000000 | total: 5471.000000
# val Loss : 0.0026
# val Acc : 0.9095
# VAL EPOCH corrects: 553.000000 | total: 608.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  0.00048150535440072417
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9746
# TRAIN EPOCH corrects: 5332.000000 | total: 5471.000000
# val Loss : 0.0009
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  0.0003393444058019668
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9719
# TRAIN EPOCH corrects: 5317.000000 | total: 5471.000000
# val Loss : 0.0017
# val Acc : 0.9375
# VAL EPOCH corrects: 570.000000 | total: 608.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.00024428043980151415
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9821
# TRAIN EPOCH corrects: 5373.000000 | total: 5471.000000
# val Loss : 0.0011
# val Acc : 0.9375
# VAL EPOCH corrects: 570.000000 | total: 608.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  0.00023718054580967873
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9792
# TRAIN EPOCH corrects: 5357.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9293
# VAL EPOCH corrects: 565.000000 | total: 608.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  0.0001812878472264856
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9821
# TRAIN EPOCH corrects: 5373.000000 | total: 5471.000000
# val Loss : 0.0024
# val Acc : 0.9128
# VAL EPOCH corrects: 555.000000 | total: 608.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  0.0006630901480093598
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9837
# TRAIN EPOCH corrects: 5382.000000 | total: 5471.000000
# val Loss : 0.0008
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  0.00014460984675679356
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9843
# TRAIN EPOCH corrects: 5385.000000 | total: 5471.000000
# val Loss : 0.0010
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  0.00024937657872214913
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9834
# TRAIN EPOCH corrects: 5380.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  0.00016879261238500476
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9810
# TRAIN EPOCH corrects: 5367.000000 | total: 5471.000000
# val Loss : 0.0009
# val Acc : 0.9622
# VAL EPOCH corrects: 585.000000 | total: 608.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  0.0002237003791378811
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9850
# TRAIN EPOCH corrects: 5389.000000 | total: 5471.000000
# val Loss : 0.0009
# val Acc : 0.9622
# VAL EPOCH corrects: 585.000000 | total: 608.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  0.0001907825208036229
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9848
# TRAIN EPOCH corrects: 5388.000000 | total: 5471.000000
# val Loss : 0.0019
# val Acc : 0.9194
# VAL EPOCH corrects: 559.000000 | total: 608.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  0.00010936337639577687
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9885
# TRAIN EPOCH corrects: 5408.000000 | total: 5471.000000
# val Loss : 0.0023
# val Acc : 0.9326
# VAL EPOCH corrects: 567.000000 | total: 608.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  0.00017741498595569283
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9870
# TRAIN EPOCH corrects: 5400.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  0.00018056102271657437
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9872
# TRAIN EPOCH corrects: 5401.000000 | total: 5471.000000
# val Loss : 0.0017
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  9.217373008141294e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9879
# TRAIN EPOCH corrects: 5405.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9375
# VAL EPOCH corrects: 570.000000 | total: 608.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  9.571950067766011e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9881
# TRAIN EPOCH corrects: 5406.000000 | total: 5471.000000
# val Loss : 0.0014
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  0.00012461455480661243
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9885
# TRAIN EPOCH corrects: 5408.000000 | total: 5471.000000
# val Loss : 0.0011
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  5.354998938855715e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9916
# TRAIN EPOCH corrects: 5425.000000 | total: 5471.000000
# val Loss : 0.0022
# val Acc : 0.9293
# VAL EPOCH corrects: 565.000000 | total: 608.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  0.0003828281769528985
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9892
# TRAIN EPOCH corrects: 5412.000000 | total: 5471.000000
# val Loss : 0.0011
# val Acc : 0.9622
# VAL EPOCH corrects: 585.000000 | total: 608.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  0.00010209030733676627
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 5444.000000 | total: 5471.000000
# val Loss : 0.0011
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  0.0001029421400744468
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9910
# TRAIN EPOCH corrects: 5422.000000 | total: 5471.000000
# val Loss : 0.0035
# val Acc : 0.9178
# VAL EPOCH corrects: 558.000000 | total: 608.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  0.00016698882973287255
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9936
# TRAIN EPOCH corrects: 5436.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  0.00011324802471790463
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9940
# TRAIN EPOCH corrects: 5438.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  0.00017349242989439517
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9940
# TRAIN EPOCH corrects: 5438.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0007
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  1.689756754785776e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9914
# TRAIN EPOCH corrects: 5424.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  0.00020195812976453453
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9918
# TRAIN EPOCH corrects: 5426.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  0.00014027382712811232
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9940
# TRAIN EPOCH corrects: 5438.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  3.5861245123669505e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9934
# TRAIN EPOCH corrects: 5435.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  7.753924728604034e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9963
# TRAIN EPOCH corrects: 5451.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  4.5121825678506866e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9956
# TRAIN EPOCH corrects: 5447.000000 | total: 5471.000000
# val Loss : 0.0022
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  0.00014319515321403742
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 5444.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 41/99
# ----------
# Iter :  0
# running_loss :  4.05707469326444e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9938
# TRAIN EPOCH corrects: 5437.000000 | total: 5471.000000
# val Loss : 0.0030
# val Acc : 0.9260
# VAL EPOCH corrects: 563.000000 | total: 608.000000
# Epoch 42/99
# ----------
# Iter :  0
# running_loss :  0.00011154594540130347
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9927
# TRAIN EPOCH corrects: 5431.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 43/99
# ----------
# Iter :  0
# running_loss :  4.7408801037818193e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9952
# TRAIN EPOCH corrects: 5445.000000 | total: 5471.000000
# val Loss : 0.0028
# val Acc : 0.9276
# VAL EPOCH corrects: 564.000000 | total: 608.000000
# Epoch 44/99
# ----------
# Iter :  0
# running_loss :  4.394276766106486e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9927
# TRAIN EPOCH corrects: 5431.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 45/99
# ----------
# Iter :  0
# running_loss :  4.0976239688461646e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9962
# TRAIN EPOCH corrects: 5450.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9408
# VAL EPOCH corrects: 572.000000 | total: 608.000000
# Epoch 46/99
# ----------
# Iter :  0
# running_loss :  6.129600660642609e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5457.000000 | total: 5471.000000
# val Loss : 0.0024
# val Acc : 0.9260
# VAL EPOCH corrects: 563.000000 | total: 608.000000
# Epoch 47/99
# ----------
# Iter :  0
# running_loss :  0.00011422570241848007
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9954
# TRAIN EPOCH corrects: 5446.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 48/99
# ----------
# Iter :  0
# running_loss :  0.00021802909031976014
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9954
# TRAIN EPOCH corrects: 5446.000000 | total: 5471.000000
# val Loss : 0.0022
# val Acc : 0.9194
# VAL EPOCH corrects: 559.000000 | total: 608.000000
# Epoch 49/99
# ----------
# Iter :  0
# running_loss :  0.0005705564981326461
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9936
# TRAIN EPOCH corrects: 5436.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 50/99
# ----------
# Iter :  0
# running_loss :  3.99621894757729e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9954
# TRAIN EPOCH corrects: 5446.000000 | total: 5471.000000
# val Loss : 0.0011
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 51/99
# ----------
# Iter :  0
# running_loss :  5.097535176901147e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5455.000000 | total: 5471.000000
# val Loss : 0.0011
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 52/99
# ----------
# Iter :  0
# running_loss :  3.9671715057920665e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9947
# TRAIN EPOCH corrects: 5442.000000 | total: 5471.000000
# val Loss : 0.0014
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  2.335195313207805e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5457.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  0.00011165780597366393
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9932
# TRAIN EPOCH corrects: 5434.000000 | total: 5471.000000
# val Loss : 0.0009
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  5.492533091455698e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 5459.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  2.0406165276654065e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9952
# TRAIN EPOCH corrects: 5445.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  2.871565993700642e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 5459.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  4.196785812382586e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9967
# TRAIN EPOCH corrects: 5453.000000 | total: 5471.000000
# val Loss : 0.0023
# val Acc : 0.9260
# VAL EPOCH corrects: 563.000000 | total: 608.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  0.0001275067188544199
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9952
# TRAIN EPOCH corrects: 5445.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  8.010658348212019e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5460.000000 | total: 5471.000000
# val Loss : 0.0022
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  0.00014440555241890252
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 5456.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  8.781624273979105e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5458.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  2.3438002244802192e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5466.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  4.177995288046077e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5455.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  1.0905124327109661e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5464.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  5.824917752761394e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5465.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  2.0441017113626003e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5458.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  1.08945769170532e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 5456.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  1.0577957255009096e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5463.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  1.497160155849997e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9967
# TRAIN EPOCH corrects: 5453.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  5.733539001084864e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5455.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9408
# VAL EPOCH corrects: 572.000000 | total: 608.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  1.9391969544813037e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 5456.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  0.00010201094846706837
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5457.000000 | total: 5471.000000
# val Loss : 0.0025
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  3.0153443731251173e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9960
# TRAIN EPOCH corrects: 5449.000000 | total: 5471.000000
# val Loss : 0.0014
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  1.1410565093683545e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5466.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  1.2218374649819452e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5463.000000 | total: 5471.000000
# val Loss : 0.0014
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  6.85847262502648e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5458.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  1.0689782357076183e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5457.000000 | total: 5471.000000
# val Loss : 0.0019
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  5.105894524604082e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9982
# TRAIN EPOCH corrects: 5461.000000 | total: 5471.000000
# val Loss : 0.0023
# val Acc : 0.9293
# VAL EPOCH corrects: 565.000000 | total: 608.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  2.3577100364491343e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9982
# TRAIN EPOCH corrects: 5461.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  1.2189795597805642e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5462.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  9.181434870697558e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5457.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  4.288618583814241e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 5456.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  3.452698001638055e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5463.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  1.0866899174288847e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5457.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  0.00011533524229889736
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5460.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  4.617107333615422e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9978
# TRAIN EPOCH corrects: 5459.000000 | total: 5471.000000
# val Loss : 0.0025
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  0.0002188282087445259
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5455.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  1.0452603419253137e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9967
# TRAIN EPOCH corrects: 5453.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  4.711294423032086e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9982
# TRAIN EPOCH corrects: 5461.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  1.6494092051289044e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9982
# TRAIN EPOCH corrects: 5461.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  5.447018338600174e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5466.000000 | total: 5471.000000
# val Loss : 0.0022
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  9.974519343813881e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5464.000000 | total: 5471.000000
# val Loss : 0.0026
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  8.471092587569728e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 5459.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  2.0916519133606926e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5458.000000 | total: 5471.000000
# val Loss : 0.0017
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  4.471490683499724e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5463.000000 | total: 5471.000000
# val Loss : 0.0023
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  6.9681946115451865e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5460.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  1.1178693966940045e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5466.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  6.08677146374248e-05
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 5456.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.21715338031450906
# EVAL ACC :  0.9452662721893491
# Predictions | Labels
# [[17 17]
#  [13 13]
#  [16 16]
#  [12 12]
#  [ 0  0]
#  [14 14]
#  [ 0  0]
#  [ 0  0]
#  [18 18]
#  [17 17]
#  [ 8  8]
#  [17 17]
#  [ 8  8]
#  [17 17]
#  [17 17]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 20 classes from 2000 features
# ['Central_venous_LSECs' 'Cholangiocytes' 'Erythroid_Cells'
#  'Hepatic_Stellate_Cells' 'Hepatocyte_1' 'Hepatocyte_2' 'Hepatocyte_3'
#  'Hepatocyte_4' 'Hepatocyte_5' 'Hepatocyte_6' 'Inflammatory_Macrophage'
#  'Mature_B_Cells' 'NK-like_Cells' 'Non-inflammatory_Macrophage'
#  'Periportal_LSECs' 'Plasma_Cells' 'Portal_endothelial_Cells'
#  'alpha-beta_T_Cells' 'gamma-delta_T_Cells_1' 'gamma-delta_T_Cells_2']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 39.51it/s]
# Extracting model embeddings...
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (6755, 2000)
# y:  (6755,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.012251749634742737
# running_acc  :  0.0390625
# corrects: 10.000000 | total: 256.000000
# train Loss : 0.0061
# train Acc : 0.5756
# TRAIN EPOCH corrects: 3149.000000 | total: 5471.000000
# val Loss : 0.0045
# val Acc : 0.7401
# VAL EPOCH corrects: 450.000000 | total: 608.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0032649219501763582
# running_acc  :  0.77734375
# corrects: 199.000000 | total: 256.000000
# train Loss : 0.0025
# train Acc : 0.8318
# TRAIN EPOCH corrects: 4551.000000 | total: 5471.000000
# val Loss : 0.0022
# val Acc : 0.9112
# VAL EPOCH corrects: 554.000000 | total: 608.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.001506959437392652
# running_acc  :  0.91796875
# corrects: 235.000000 | total: 256.000000
# train Loss : 0.0017
# train Acc : 0.8920
# TRAIN EPOCH corrects: 4880.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.8750
# VAL EPOCH corrects: 532.000000 | total: 608.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.0012173437280580401
# running_acc  :  0.91796875
# corrects: 235.000000 | total: 256.000000
# train Loss : 0.0012
# train Acc : 0.9201
# TRAIN EPOCH corrects: 5034.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.8931
# VAL EPOCH corrects: 543.000000 | total: 608.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.0009543835185468197
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# train Loss : 0.0009
# train Acc : 0.9395
# TRAIN EPOCH corrects: 5140.000000 | total: 5471.000000
# val Loss : 0.0023
# val Acc : 0.8980
# VAL EPOCH corrects: 546.000000 | total: 608.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0010358458384871483
# running_acc  :  0.9140625
# corrects: 234.000000 | total: 256.000000
# train Loss : 0.0008
# train Acc : 0.9411
# TRAIN EPOCH corrects: 5149.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0023
# val Acc : 0.8964
# VAL EPOCH corrects: 545.000000 | total: 608.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.0006613799487240613
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9541
# TRAIN EPOCH corrects: 5220.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0018
# val Acc : 0.9326
# VAL EPOCH corrects: 567.000000 | total: 608.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.0005120690912008286
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9550
# TRAIN EPOCH corrects: 5225.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0016
# val Acc : 0.9227
# VAL EPOCH corrects: 561.000000 | total: 608.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.0003120005421806127
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9695
# TRAIN EPOCH corrects: 5304.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9359
# VAL EPOCH corrects: 569.000000 | total: 608.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.000358064251486212
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9656
# TRAIN EPOCH corrects: 5283.000000 | total: 5471.000000
# val Loss : 0.0022
# val Acc : 0.9243
# VAL EPOCH corrects: 562.000000 | total: 608.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  0.000527629628777504
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9737
# TRAIN EPOCH corrects: 5327.000000 | total: 5471.000000
# val Loss : 0.0029
# val Acc : 0.8914
# VAL EPOCH corrects: 542.000000 | total: 608.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  0.00044724540202878416
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9728
# TRAIN EPOCH corrects: 5322.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9326
# VAL EPOCH corrects: 567.000000 | total: 608.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.0002495416847523302
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9724
# TRAIN EPOCH corrects: 5320.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.8964
# VAL EPOCH corrects: 545.000000 | total: 608.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  0.0007504494278691709
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9731
# TRAIN EPOCH corrects: 5324.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0012
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  0.00037960021290928125
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9795
# TRAIN EPOCH corrects: 5359.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0009
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  0.00020688782387878746
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9841
# TRAIN EPOCH corrects: 5384.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9408
# VAL EPOCH corrects: 572.000000 | total: 608.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  0.0001987504365388304
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9846
# TRAIN EPOCH corrects: 5387.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9375
# VAL EPOCH corrects: 570.000000 | total: 608.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  0.00024260161444544792
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9835
# TRAIN EPOCH corrects: 5381.000000 | total: 5471.000000
# val Loss : 0.0014
# val Acc : 0.9227
# VAL EPOCH corrects: 561.000000 | total: 608.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  0.0001515285694040358
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9859
# TRAIN EPOCH corrects: 5394.000000 | total: 5471.000000
# val Loss : 0.0026
# val Acc : 0.9342
# VAL EPOCH corrects: 568.000000 | total: 608.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  0.0001628945319680497
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9825
# TRAIN EPOCH corrects: 5375.000000 | total: 5471.000000
# val Loss : 0.0010
# val Acc : 0.9260
# VAL EPOCH corrects: 563.000000 | total: 608.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  0.00019789469661191106
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9874
# TRAIN EPOCH corrects: 5402.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  0.00012127605441492051
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9907
# TRAIN EPOCH corrects: 5420.000000 | total: 5471.000000
# val Loss : 0.0031
# val Acc : 0.9062
# VAL EPOCH corrects: 551.000000 | total: 608.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  0.00012320636596996337
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9865
# TRAIN EPOCH corrects: 5397.000000 | total: 5471.000000
# val Loss : 0.0011
# val Acc : 0.9408
# VAL EPOCH corrects: 572.000000 | total: 608.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  0.00018978773732669652
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9872
# TRAIN EPOCH corrects: 5401.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9342
# VAL EPOCH corrects: 568.000000 | total: 608.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  0.0002251543919555843
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9887
# TRAIN EPOCH corrects: 5409.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9342
# VAL EPOCH corrects: 568.000000 | total: 608.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  0.00017408198618795723
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9872
# TRAIN EPOCH corrects: 5401.000000 | total: 5471.000000
# val Loss : 0.0026
# val Acc : 0.9375
# VAL EPOCH corrects: 570.000000 | total: 608.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  0.00024779309751465917
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9929
# TRAIN EPOCH corrects: 5432.000000 | total: 5471.000000
# val Loss : 0.0014
# val Acc : 0.9326
# VAL EPOCH corrects: 567.000000 | total: 608.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  0.00017902629042509943
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9914
# TRAIN EPOCH corrects: 5424.000000 | total: 5471.000000
# val Loss : 0.0030
# val Acc : 0.9227
# VAL EPOCH corrects: 561.000000 | total: 608.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  8.125884778564796e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9863
# TRAIN EPOCH corrects: 5396.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9309
# VAL EPOCH corrects: 566.000000 | total: 608.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  0.0001129083102568984
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9920
# TRAIN EPOCH corrects: 5427.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  5.117188629810698e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9905
# TRAIN EPOCH corrects: 5419.000000 | total: 5471.000000
# val Loss : 0.0019
# val Acc : 0.9342
# VAL EPOCH corrects: 568.000000 | total: 608.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  0.00012952029646839947
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9907
# TRAIN EPOCH corrects: 5420.000000 | total: 5471.000000
# val Loss : 0.0019
# val Acc : 0.9260
# VAL EPOCH corrects: 563.000000 | total: 608.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  8.501100091962144e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9938
# TRAIN EPOCH corrects: 5437.000000 | total: 5471.000000
# val Loss : 0.0019
# val Acc : 0.9359
# VAL EPOCH corrects: 569.000000 | total: 608.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  6.836164538981393e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9921
# TRAIN EPOCH corrects: 5428.000000 | total: 5471.000000
# val Loss : 0.0031
# val Acc : 0.9194
# VAL EPOCH corrects: 559.000000 | total: 608.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  0.00016798617434687912
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9916
# TRAIN EPOCH corrects: 5425.000000 | total: 5471.000000
# val Loss : 0.0019
# val Acc : 0.9375
# VAL EPOCH corrects: 570.000000 | total: 608.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  8.18800472188741e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9936
# TRAIN EPOCH corrects: 5436.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  5.031560067436658e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 5444.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9326
# VAL EPOCH corrects: 567.000000 | total: 608.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  0.00011810778232757002
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9934
# TRAIN EPOCH corrects: 5435.000000 | total: 5471.000000
# val Loss : 0.0025
# val Acc : 0.9276
# VAL EPOCH corrects: 564.000000 | total: 608.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  5.484687062562443e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9943
# TRAIN EPOCH corrects: 5440.000000 | total: 5471.000000
# val Loss : 0.0012
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  2.8394733817549422e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# ...
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  0.00012373212666716427
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9967
# TRAIN EPOCH corrects: 5454.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9638
# VAL EPOCH corrects: 586.000000 | total: 608.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  7.695289241382852e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5456.000000 | total: 5472.000000
# val Loss : 0.0011
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  4.56870038760826e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5456.000000 | total: 5472.000000
# val Loss : 0.0006
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  8.176676055882126e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9969
# TRAIN EPOCH corrects: 5455.000000 | total: 5472.000000
# val Loss : 0.0043
# val Acc : 0.8849
# VAL EPOCH corrects: 538.000000 | total: 608.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  0.00012856762623414397
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9962
# TRAIN EPOCH corrects: 5451.000000 | total: 5472.000000
# val Loss : 0.0010
# val Acc : 0.9622
# VAL EPOCH corrects: 585.000000 | total: 608.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  1.3270366252982058e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9958
# TRAIN EPOCH corrects: 5449.000000 | total: 5472.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0005
# val Acc : 0.9638
# VAL EPOCH corrects: 586.000000 | total: 608.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  2.894664248742629e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9965
# TRAIN EPOCH corrects: 5453.000000 | total: 5472.000000
# val Loss : 0.0010
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  5.728067480958998e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9963
# TRAIN EPOCH corrects: 5452.000000 | total: 5472.000000
# val Loss : 0.0006
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  0.0001050963401212357
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9969
# TRAIN EPOCH corrects: 5455.000000 | total: 5472.000000
# val Loss : 0.0005
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  3.234562245779671e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5456.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9622
# VAL EPOCH corrects: 585.000000 | total: 608.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  1.3256184502097312e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9960
# TRAIN EPOCH corrects: 5450.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  7.526149420300499e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5458.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  1.8946975615108386e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9969
# TRAIN EPOCH corrects: 5455.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  3.925932469428517e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 5460.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9605
# VAL EPOCH corrects: 584.000000 | total: 608.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  2.1455116439028643e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5458.000000 | total: 5472.000000
# val Loss : 0.0010
# val Acc : 0.9622
# VAL EPOCH corrects: 585.000000 | total: 608.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  1.2429636626620777e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5461.000000 | total: 5472.000000
# val Loss : 0.0011
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  6.591879355255514e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5463.000000 | total: 5472.000000
# val Loss : 0.0011
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  1.847360545070842e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5464.000000 | total: 5472.000000
# val Loss : 0.0015
# val Acc : 0.9375
# VAL EPOCH corrects: 570.000000 | total: 608.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  0.00026738198357634246
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5459.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9655
# VAL EPOCH corrects: 587.000000 | total: 608.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  4.582855763146654e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 5460.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  9.767862138687633e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 5457.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9655
# VAL EPOCH corrects: 587.000000 | total: 608.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  2.3535621949122287e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5465.000000 | total: 5472.000000
# val Loss : 0.0015
# val Acc : 0.9622
# VAL EPOCH corrects: 585.000000 | total: 608.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  4.0709848690312356e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9973
# TRAIN EPOCH corrects: 5457.000000 | total: 5472.000000
# val Loss : 0.0020
# val Acc : 0.9243
# VAL EPOCH corrects: 562.000000 | total: 608.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  0.00011048515443690121
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9982
# TRAIN EPOCH corrects: 5462.000000 | total: 5472.000000
# val Loss : 0.0016
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  1.4309553080238402e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9982
# TRAIN EPOCH corrects: 5462.000000 | total: 5472.000000
# val Loss : 0.0013
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  7.786381502228323e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9963
# TRAIN EPOCH corrects: 5452.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  1.1980590898019727e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5466.000000 | total: 5472.000000
# val Loss : 0.0010
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  2.4250830392702483e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5464.000000 | total: 5472.000000
# val Loss : 0.0005
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  4.621841435437091e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5459.000000 | total: 5472.000000
# val Loss : 0.0017
# val Acc : 0.9375
# VAL EPOCH corrects: 570.000000 | total: 608.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  6.772812776034698e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5461.000000 | total: 5472.000000
# val Loss : 0.0006
# val Acc : 0.9622
# VAL EPOCH corrects: 585.000000 | total: 608.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  4.541533417068422e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9978
# TRAIN EPOCH corrects: 5460.000000 | total: 5472.000000
# val Loss : 0.0016
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  1.4382208064489532e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 5460.000000 | total: 5472.000000
# val Loss : 0.0007
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  8.452659130853135e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5459.000000 | total: 5472.000000
# val Loss : 0.0018
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  1.686310497461818e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5464.000000 | total: 5472.000000
# val Loss : 0.0015
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  3.905991979991086e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5459.000000 | total: 5472.000000
# val Loss : 0.0015
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  3.380253110663034e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5456.000000 | total: 5472.000000
# val Loss : 0.0020
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  4.6971530537121e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5459.000000 | total: 5472.000000
# val Loss : 0.0010
# val Acc : 0.9622
# VAL EPOCH corrects: 585.000000 | total: 608.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  8.072309356066398e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5459.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  4.304396134102717e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5456.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  3.796358942054212e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5464.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  3.0718241760041565e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5461.000000 | total: 5472.000000
# val Loss : 0.0011
# val Acc : 0.9622
# VAL EPOCH corrects: 585.000000 | total: 608.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  1.6193653209484182e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5465.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  6.245288386708125e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5463.000000 | total: 5472.000000
# val Loss : 0.0010
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  7.403425115626305e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5458.000000 | total: 5472.000000
# val Loss : 0.0013
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  2.374216273892671e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9967
# TRAIN EPOCH corrects: 5454.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9638
# VAL EPOCH corrects: 586.000000 | total: 608.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  1.1128744517918676e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5465.000000 | total: 5472.000000
# val Loss : 0.0015
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  1.0822646800079383e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5467.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.27016326785087585
# EVAL ACC :  0.9467455621301775
# Predictions | Labels
# [[17 17]
#  [13 13]
#  [12 12]
#  [12 12]
#  [17 17]
#  [17 17]
#  [ 0  0]
#  [17 17]
#  [17 17]
#  [18 18]
#  [13 13]
#  [12 12]
#  [17 17]
#  [ 0  0]
#  [17 17]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 20 classes from 2000 features
# ['Central_venous_LSECs' 'Cholangiocytes' 'Erythroid_Cells'
#  'Hepatic_Stellate_Cells' 'Hepatocyte_1' 'Hepatocyte_2' 'Hepatocyte_3'
#  'Hepatocyte_4' 'Hepatocyte_5' 'Hepatocyte_6' 'Inflammatory_Macrophage'
#  'Mature_B_Cells' 'NK-like_Cells' 'Non-inflammatory_Macrophage'
#  'Periportal_LSECs' 'Plasma_Cells' 'Portal_endothelial_Cells'
#  'alpha-beta_T_Cells' 'gamma-delta_T_Cells_1' 'gamma-delta_T_Cells_2']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 25.60it/s]
# Extracting model embeddings...

# %%
# Save results
results.to_csv('results/scNym_hvgs_output.csv', index=True)

# %%
# Extract the unique labels
unique_labels1 = np.unique(results.true_label)
unique_labels2 = np.unique(results.pred)
unique_labels = np.unique(np.concatenate([unique_labels1,unique_labels2]))

# Convert string labels to numerical labels
label_encoder_temp = LabelEncoder()
label_encoder_temp.fit(unique_labels)
y_true = label_encoder_temp.transform(results.true_label)
y_pred = label_encoder_temp.transform(results.pred)

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.946470866887731
