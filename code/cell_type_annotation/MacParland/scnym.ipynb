# %% [markdown]
# ## scNym: https://github.com/calico/scnym

# %%
import scnym
from scnym.api import scnym_api
import torch
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import scanpy as sc
# Out:
# WARNING:tensorflow:From c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def split_data(data_path: str, 
               fold: int=1,
               folds: int=5,
               batch_key: str="patientID", 
               label_key: str="cell_type",
               seed: int=42,
               HVG: bool=False,
               HVGs: int=2000):
    
    adata = sc.read(data_path, cache=True)

    adata.obs["batch"] = adata.obs[batch_key]

    # Ensure reproducibility
    def rep_seed(seed):
        # Check if a GPU is available
        if torch.cuda.is_available():
            # Set the random seed for PyTorch CUDA (GPU) operations
            torch.cuda.manual_seed(seed)
            # Set the random seed for all CUDA devices (if multiple GPUs are available)
            torch.cuda.manual_seed_all(seed)
        
        # Set the random seed for CPU-based PyTorch operations
        torch.manual_seed(seed)
        
        # Set the random seed for NumPy
        np.random.seed(seed)
        
        # Set the random seed for Python's built-in 'random' module
        random.seed(seed)
        
        # Set the random seed for TensorFlow
        tf.random.set_seed(seed)
        
        # Set CuDNN to deterministic mode for PyTorch (GPU)
        torch.backends.cudnn.deterministic = True
        
        # Disable CuDNN's benchmarking mode for deterministic behavior
        torch.backends.cudnn.benchmark = False

    rep_seed(seed)

    # Initialize Stratified K-Fold
    stratified_kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)

    # Iterate through the folds
    adata_original = adata.copy()
    test_adata_original = adata.copy()
    fold_counter = 0
    for train_index, test_index in stratified_kfold.split(adata_original.X, adata_original.obs[label_key]):
        fold_counter += 1
        
        adata = adata_original[train_index, :].copy()
        test_adata = test_adata_original[test_index, :].copy()

        if HVG:
            sc.pp.highly_variable_genes(adata, n_top_genes=HVGs, flavor="cell_ranger")
            test_adata = test_adata[:, adata.var["highly_variable"]].copy()
            adata = adata[:, adata.var["highly_variable"]].copy()
        
        if fold_counter == fold:
            
            return adata, test_adata

# %%
data_path = "../../../data/processed/data_for_evaluating_cell_type_annotation/MacParland.h5ad"

# Iterate through folds
results = None
for fold_idx in range(5):
    fold = fold_idx + 1

    adata_train, adata_test = split_data(data_path=data_path, fold=fold)

    # Train model
    scnym_api(
        adata=adata_train,
        task='train',
        groupby='cell_type',
        out_path='./scnym_outputs',
        config='no_new_identity',
    )

    # Predict test data
    scnym_api(
        adata=adata_test,
        task='predict',
        key_added='scNym',
        config='no_new_identity',
        trained_model='./scnym_outputs'
    )

    # Save results in dataframe
    if fold == 1:
        results = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                "true_label": adata_test.obs["cell_type"].to_list(), 
                                "fold": [fold]*adata_test.obs['scNym'].shape[0]})
    else:   
        dataframe_temp = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                    "true_label": adata_test.obs["cell_type"].to_list(), 
                                    "fold": [fold]*adata_test.obs['scNym'].shape[0]})
        results = pd.concat([results,dataframe_temp], axis=0)

# Reset index
results.reset_index(drop=True, inplace=True)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (6755, 15386)
# y:  (6755,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.01210148073732853
# running_acc  :  0.0546875
# corrects: 14.000000 | total: 256.000000
# train Loss : 0.0059
# train Acc : 0.5853
# TRAIN EPOCH corrects: 3202.000000 | total: 5471.000000
# val Loss : 0.0048
# val Acc : 0.7714
# VAL EPOCH corrects: 469.000000 | total: 608.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.002864859299734235
# running_acc  :  0.80859375
# corrects: 207.000000 | total: 256.000000
# train Loss : 0.0023
# train Acc : 0.8450
# TRAIN EPOCH corrects: 4623.000000 | total: 5471.000000
# val Loss : 0.0027
# val Acc : 0.8799
# VAL EPOCH corrects: 535.000000 | total: 608.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.0017449489096179605
# running_acc  :  0.8828125
# corrects: 226.000000 | total: 256.000000
# train Loss : 0.0012
# train Acc : 0.9265
# TRAIN EPOCH corrects: 5069.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9178
# VAL EPOCH corrects: 558.000000 | total: 608.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.0009213263401761651
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# train Loss : 0.0008
# train Acc : 0.9576
# TRAIN EPOCH corrects: 5239.000000 | total: 5471.000000
# val Loss : 0.0027
# val Acc : 0.8717
# VAL EPOCH corrects: 530.000000 | total: 608.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.0005471550393849611
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9731
# TRAIN EPOCH corrects: 5324.000000 | total: 5471.000000
# val Loss : 0.0011
# val Acc : 0.9293
# VAL EPOCH corrects: 565.000000 | total: 608.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.000406522216508165
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9815
# TRAIN EPOCH corrects: 5370.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0013
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.0002969386987388134
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9885
# TRAIN EPOCH corrects: 5408.000000 | total: 5471.000000
# val Loss : 0.0017
# val Acc : 0.9194
# VAL EPOCH corrects: 559.000000 | total: 608.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.0003078762674704194
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9887
# TRAIN EPOCH corrects: 5409.000000 | total: 5471.000000
# val Loss : 0.0058
# val Acc : 0.8454
# VAL EPOCH corrects: 514.000000 | total: 608.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.000548467505723238
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9901
# TRAIN EPOCH corrects: 5417.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0011
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.00019139748474117368
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9912
# TRAIN EPOCH corrects: 5423.000000 | total: 5471.000000
# val Loss : 0.0037
# val Acc : 0.8322
# VAL EPOCH corrects: 506.000000 | total: 608.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  0.00019894079014193267
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9914
# TRAIN EPOCH corrects: 5424.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0009
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  0.00020218954887241125
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9942
# TRAIN EPOCH corrects: 5439.000000 | total: 5471.000000
# val Loss : 0.0009
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  7.849247776903212e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9954
# TRAIN EPOCH corrects: 5446.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9359
# VAL EPOCH corrects: 569.000000 | total: 608.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  0.0001281335426028818
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9945
# TRAIN EPOCH corrects: 5441.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  5.3395324357552454e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9963
# TRAIN EPOCH corrects: 5451.000000 | total: 5471.000000
# val Loss : 0.0017
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  6.67319618514739e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 5444.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  4.812033876078203e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9954
# TRAIN EPOCH corrects: 5446.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  8.238667214754969e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9969
# TRAIN EPOCH corrects: 5454.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  3.634749009506777e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5457.000000 | total: 5471.000000
# val Loss : 0.0010
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  1.5092629837454297e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9967
# TRAIN EPOCH corrects: 5453.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0009
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  6.266457785386592e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5457.000000 | total: 5471.000000
# val Loss : 0.0009
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  2.1608588212984614e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5462.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  2.6672443709685467e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9982
# TRAIN EPOCH corrects: 5461.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  2.1882844521314837e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5462.000000 | total: 5471.000000
# val Loss : 0.0010
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  2.5207769795088097e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5462.000000 | total: 5471.000000
# val Loss : 0.0019
# val Acc : 0.9408
# VAL EPOCH corrects: 572.000000 | total: 608.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  2.7233691071160138e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9982
# TRAIN EPOCH corrects: 5461.000000 | total: 5471.000000
# val Loss : 0.0011
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  1.1875364180014003e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5465.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  1.7220147128682584e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5463.000000 | total: 5471.000000
# val Loss : 0.0019
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  4.261491631041281e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5458.000000 | total: 5471.000000
# val Loss : 0.0011
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :
000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.003031804459169507
# running_acc  :  0.7890625
# corrects: 202.000000 | total: 256.000000
# train Loss : 0.0024
# train Acc : 0.8439
# TRAIN EPOCH corrects: 4617.000000 | total: 5471.000000
# val Loss : 0.0051
# val Acc : 0.6480
# VAL EPOCH corrects: 394.000000 | total: 608.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.0017325602238997817
# running_acc  :  0.890625
# corrects: 228.000000 | total: 256.000000
# train Loss : 0.0013
# train Acc : 0.9214
# TRAIN EPOCH corrects: 5041.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.8799
# VAL EPOCH corrects: 535.000000 | total: 608.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.0009651544387452304
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# train Loss : 0.0008
# train Acc : 0.9506
# TRAIN EPOCH corrects: 5201.000000 | total: 5471.000000
# val Loss : 0.0014
# val Acc : 0.9178
# VAL EPOCH corrects: 558.000000 | total: 608.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.0006838652770966291
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9686
# TRAIN EPOCH corrects: 5299.000000 | total: 5471.000000
# val Loss : 0.0023
# val Acc : 0.8635
# VAL EPOCH corrects: 525.000000 | total: 608.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0003797489625867456
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9797
# TRAIN EPOCH corrects: 5360.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0026
# val Acc : 0.8882
# VAL EPOCH corrects: 540.000000 | total: 608.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.00025870732497423887
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9808
# TRAIN EPOCH corrects: 5366.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0012
# val Acc : 0.9359
# VAL EPOCH corrects: 569.000000 | total: 608.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.0002204736665589735
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9837
# TRAIN EPOCH corrects: 5382.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0012
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.0002461905241943896
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9914
# TRAIN EPOCH corrects: 5424.000000 | total: 5471.000000
# val Loss : 0.0014
# val Acc : 0.9408
# VAL EPOCH corrects: 572.000000 | total: 608.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.00010554042819421738
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9936
# TRAIN EPOCH corrects: 5436.000000 | total: 5471.000000
# val Loss : 0.0013
# val Acc : 0.9359
# VAL EPOCH corrects: 569.000000 | total: 608.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  0.00016438178136013448
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9905
# TRAIN EPOCH corrects: 5419.000000 | total: 5471.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0009
# val Acc : 0.9359
# VAL EPOCH corrects: 569.000000 | total: 608.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  8.29725104267709e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9910
# TRAIN EPOCH corrects: 5422.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9276
# VAL EPOCH corrects: 564.000000 | total: 608.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.0001113375838031061
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9947
# TRAIN EPOCH corrects: 5442.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9326
# VAL EPOCH corrects: 567.000000 | total: 608.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  7.946848927531391e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9947
# TRAIN EPOCH corrects: 5442.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  6.2702783907298e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9940
# TRAIN EPOCH corrects: 5438.000000 | total: 5471.000000
# val Loss : 0.0023
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  6.209169805515558e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9969
# TRAIN EPOCH corrects: 5454.000000 | total: 5471.000000
# val Loss : 0.0014
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  5.33911916136276e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9960
# TRAIN EPOCH corrects: 5449.000000 | total: 5471.000000
# val Loss : 0.0017
# val Acc : 0.9342
# VAL EPOCH corrects: 568.000000 | total: 608.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  6.561168265761808e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9923
# TRAIN EPOCH corrects: 5429.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9359
# VAL EPOCH corrects: 569.000000 | total: 608.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  3.8010755815776065e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5455.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9326
# VAL EPOCH corrects: 567.000000 | total: 608.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  2.6358527975389734e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9967
# TRAIN EPOCH corrects: 5453.000000 | total: 5471.000000
# val Loss : 0.0017
# val Acc : 0.9408
# VAL EPOCH corrects: 572.000000 | total: 608.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  9.708766447147354e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5455.000000 | total: 5471.000000
# val Loss : 0.0017
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  1.7329113688901998e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9973
# TRAIN EPOCH corrects: 5456.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9342
# VAL EPOCH corrects: 568.000000 | total: 608.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  5.698457243852317e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5460.000000 | total: 5471.000000
# val Loss : 0.0026
# val Acc : 0.9326
# VAL EPOCH corrects: 567.000000 | total: 608.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  4.428535612532869e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5462.000000 | total: 5471.000000
# val Loss : 0.0017
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  4.9918955483008176e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9976
# TRAIN EPOCH corrects: 5458.000000 | total: 5471.000000
# val Loss : 0.0033
# val Acc : 0.9276
# VAL EPOCH corrects: 564.000000 | total: 608.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  3.56297823600471e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5464.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9227
# VAL EPOCH corrects: 561.000000 | total: 608.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  1.9558081476134248e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9974
# TRAIN EPOCH corrects: 5457.000000 | total: 5471.000000
# val Loss : 0.0020
# val Acc : 0.9309
# VAL EPOCH corrects: 566.000000 | total: 608.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  2.0971812773495913e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5464.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9342
# VAL EPOCH corrects: 568.000000 | total: 608.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  5.264172796159983e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5462.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  8.086914021987468e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5465.000000 | total: 5471.000000
# val Loss : 0.0019
# val Acc : 0.9441
# VAL EPOCH corrects: 574.000000 | total: 608.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  2.133074121957179e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5463.000000 | total: 5471.000000
# val Loss : 0.0019
# val Acc : 0.9359
# VAL EPOCH corrects: 569.000000 | total: 608.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  2.4462779038003646e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5460.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  2.3947486624820158e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5462.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  4.680156780523248e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5463.000000 | total: 5471.000000
# val Loss : 0.0018
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  1.7362805010634474e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5463.000000 | total: 5471.000000
# val Loss : 0.0024
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  3.181240754202008e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5467.000000 | total: 5471.000000
# val Loss : 0.0016
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  2.6353551220381632e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5466.000000 | total: 5471.000000
# val Loss : 0.0026
# val Acc : 0.9375
# VAL EPOCH corrects: 570.000000 | total: 608.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  2.6374977096566e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5469.000000 | total: 5471.000000
# val Loss : 0.0025
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  2.1494955944945104e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5466.000000 | total: 5471.000000
# val Loss : 0.0022
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  9.576035154168494e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5466.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9408
# VAL EPOCH corrects: 572.000000 | total: 608.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  1.3399941963143647e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5464.000000 | total: 5471.000000
# val Loss : 0.0015
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 41/99
# ----------
# Iter :  0
# running_loss :  1.3226781447883695e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5465.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 42/99
# ----------
# Iter :  0
# running_loss :  1.629634243727196e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5463.000000 | total: 5471.000000
# val Loss : 0.0031
# val Acc : 0.9391
# VAL EPOCH corrects: 571.000000 | total: 608.000000
# Epoch 43/99
# ----------
# Iter :  0
# running_loss :  1.6835292626637965e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5467.000000 | total: 5471.000000
# val Loss : 0.0021
# val Acc : 0.9424
# VAL EPOCH corrects: 573.000000 | total: 608.000000
# Epoch 44/99
# ----------
# Iter :  0
# running_loss :  1.2813581633963622e-05
# ...
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  5.1331617214600556e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5469.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  5.282909478410147e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5465.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  1.3908196706324816e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5465.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  6.115166343079181e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5468.000000 | total: 5472.000000
# val Loss : 0.0014
# val Acc : 0.9605
# VAL EPOCH corrects: 584.000000 | total: 608.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  4.0351293137064204e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5465.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  1.8125821952708066e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5469.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  6.181892786116805e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5471.000000 | total: 5472.000000
# val Loss : 0.0020
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  1.8456426914781332e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5468.000000 | total: 5472.000000
# val Loss : 0.0014
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  5.06415653944714e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5468.000000 | total: 5472.000000
# val Loss : 0.0010
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  1.4954782272980083e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5472.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  6.478250725194812e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  7.547645054728491e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  2.5013228878378868e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5469.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  4.58871727460064e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5466.000000 | total: 5472.000000
# val Loss : 0.0014
# val Acc : 0.9605
# VAL EPOCH corrects: 584.000000 | total: 608.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  7.40009818400722e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5468.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  8.813378371996805e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5463.000000 | total: 5472.000000
# val Loss : 0.0018
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  1.2640673048736062e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5466.000000 | total: 5472.000000
# val Loss : 0.0014
# val Acc : 0.9605
# VAL EPOCH corrects: 584.000000 | total: 608.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  6.460645636252593e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 5464.000000 | total: 5472.000000
# val Loss : 0.0015
# val Acc : 0.9605
# VAL EPOCH corrects: 584.000000 | total: 608.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  3.211946022929624e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0016
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  4.56486304756254e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5465.000000 | total: 5472.000000
# val Loss : 0.0010
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  1.4696219295728952e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  8.024259841477033e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5468.000000 | total: 5472.000000
# val Loss : 0.0011
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  2.060198676190339e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0017
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  7.974553227541037e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5469.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  5.468511972139822e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0011
# val Acc : 0.9507
# VAL EPOCH corrects: 578.000000 | total: 608.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  6.024128197168466e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5468.000000 | total: 5472.000000
# val Loss : 0.0013
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  1.2976018297194969e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5469.000000 | total: 5472.000000
# val Loss : 0.0024
# val Acc : 0.9457
# VAL EPOCH corrects: 575.000000 | total: 608.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  1.9523467926774174e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5471.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  6.066129571991041e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5467.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  4.895255642622942e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5469.000000 | total: 5472.000000
# val Loss : 0.0007
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  6.57851887808647e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5469.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9408
# VAL EPOCH corrects: 572.000000 | total: 608.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  1.5541252651019022e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5472.000000 | total: 5472.000000
# val Loss : 0.0013
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  9.469066753808875e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5467.000000 | total: 5472.000000
# val Loss : 0.0013
# val Acc : 0.9490
# VAL EPOCH corrects: 577.000000 | total: 608.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  5.432928810478188e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5468.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  1.9196488210582174e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5468.000000 | total: 5472.000000
# val Loss : 0.0011
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  6.633635621255962e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5469.000000 | total: 5472.000000
# val Loss : 0.0017
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  4.562997673929203e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0011
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  1.1584848834900185e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5468.000000 | total: 5472.000000
# val Loss : 0.0012
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  3.5005393783649197e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9556
# VAL EPOCH corrects: 581.000000 | total: 608.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  9.806856724026147e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0011
# val Acc : 0.9572
# VAL EPOCH corrects: 582.000000 | total: 608.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  5.640937615680741e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5471.000000 | total: 5472.000000
# val Loss : 0.0011
# val Acc : 0.9589
# VAL EPOCH corrects: 583.000000 | total: 608.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  5.822063940286171e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5471.000000 | total: 5472.000000
# val Loss : 0.0010
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  3.847870175377466e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0018
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  1.1390763575036544e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5472.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9539
# VAL EPOCH corrects: 580.000000 | total: 608.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  3.132893834845163e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5470.000000 | total: 5472.000000
# val Loss : 0.0008
# val Acc : 0.9474
# VAL EPOCH corrects: 576.000000 | total: 608.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  1.4113248653302435e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5467.000000 | total: 5472.000000
# val Loss : 0.0013
# val Acc : 0.9523
# VAL EPOCH corrects: 579.000000 | total: 608.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  1.0266047866025474e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5471.000000 | total: 5472.000000
# val Loss : 0.0009
# val Acc : 0.9605
# VAL EPOCH corrects: 584.000000 | total: 608.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.20656573648254076
# EVAL ACC :  0.9437869822485208
# Predictions | Labels
# [[17 17]
#  [13 13]
#  [12 12]
#  [12 12]
#  [17 17]
#  [17 17]
#  [ 0  0]
#  [17 17]
#  [17 17]
#  [18 18]
#  [13 13]
#  [12 12]
#  [17 17]
#  [ 0  0]
#  [17 17]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 20 classes from 15386 features
# ['Central_venous_LSECs' 'Cholangiocytes' 'Erythroid_Cells'
#  'Hepatic_Stellate_Cells' 'Hepatocyte_1' 'Hepatocyte_2' 'Hepatocyte_3'
#  'Hepatocyte_4' 'Hepatocyte_5' 'Hepatocyte_6' 'Inflammatory_Macrophage'
#  'Mature_B_Cells' 'NK-like_Cells' 'Non-inflammatory_Macrophage'
#  'Periportal_LSECs' 'Plasma_Cells' 'Portal_endothelial_Cells'
#  'alpha-beta_T_Cells' 'gamma-delta_T_Cells_1' 'gamma-delta_T_Cells_2']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 10.03it/s]
# Extracting model embeddings...

# %%
# Save results
results.to_csv('results/scNym_output.csv', index=True)

# %%
# Extract the unique labels
unique_labels1 = np.unique(results.true_label)
unique_labels2 = np.unique(results.pred)
unique_labels = np.unique(np.concatenate([unique_labels1,unique_labels2]))

# Convert string labels to numerical labels
label_encoder_temp = LabelEncoder()
label_encoder_temp.fit(unique_labels)
y_true = label_encoder_temp.transform(results.true_label)
y_pred = label_encoder_temp.transform(results.pred)

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9515632401705353
