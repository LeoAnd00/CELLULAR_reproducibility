# %% [markdown]
# ## scNym: https://github.com/calico/scnym

# %%
import scnym
from scnym.api import scnym_api
import torch
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import scanpy as sc
# Out:
# WARNING:tensorflow:From c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def split_data(data_path: str, 
               fold: int=1,
               folds: int=5,
               batch_key: str="patientID", 
               label_key: str="cell_type",
               seed: int=42,
               HVG: bool=False,
               HVGs: int=2000):
    
    adata = sc.read(data_path, cache=True)

    adata.obs["batch"] = adata.obs[batch_key]

    # Ensure reproducibility
    def rep_seed(seed):
        # Check if a GPU is available
        if torch.cuda.is_available():
            # Set the random seed for PyTorch CUDA (GPU) operations
            torch.cuda.manual_seed(seed)
            # Set the random seed for all CUDA devices (if multiple GPUs are available)
            torch.cuda.manual_seed_all(seed)
        
        # Set the random seed for CPU-based PyTorch operations
        torch.manual_seed(seed)
        
        # Set the random seed for NumPy
        np.random.seed(seed)
        
        # Set the random seed for Python's built-in 'random' module
        random.seed(seed)
        
        # Set the random seed for TensorFlow
        tf.random.set_seed(seed)
        
        # Set CuDNN to deterministic mode for PyTorch (GPU)
        torch.backends.cudnn.deterministic = True
        
        # Disable CuDNN's benchmarking mode for deterministic behavior
        torch.backends.cudnn.benchmark = False

    rep_seed(seed)

    # Initialize Stratified K-Fold
    stratified_kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)

    # Iterate through the folds
    adata_original = adata.copy()
    test_adata_original = adata.copy()
    fold_counter = 0
    for train_index, test_index in stratified_kfold.split(adata_original.X, adata_original.obs[label_key]):
        fold_counter += 1
        
        adata = adata_original[train_index, :].copy()
        test_adata = test_adata_original[test_index, :].copy()

        if HVG:
            sc.pp.highly_variable_genes(adata, n_top_genes=HVGs, flavor="cell_ranger")
            test_adata = test_adata[:, adata.var["highly_variable"]].copy()
            adata = adata[:, adata.var["highly_variable"]].copy()
        
        if fold_counter == fold:
            
            return adata, test_adata

# %%
data_path = "../../../data/processed/data_for_evaluating_cell_type_annotation/Baron.h5ad"

# Iterate through folds
results = None
for fold_idx in range(5):
    fold = fold_idx + 1

    adata_train, adata_test = split_data(data_path=data_path, fold=fold)

    # Train model
    scnym_api(
        adata=adata_train,
        task='train',
        groupby='cell_type',
        out_path='./scnym_outputs',
        config='no_new_identity',
    )

    # Predict test data
    scnym_api(
        adata=adata_test,
        task='predict',
        key_added='scNym',
        config='no_new_identity',
        trained_model='./scnym_outputs'
    )

    # Save results in dataframe
    if fold == 1:
        results = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                "true_label": adata_test.obs["cell_type"].to_list(), 
                                "fold": [fold]*adata_test.obs['scNym'].shape[0]})
    else:   
        dataframe_temp = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                    "true_label": adata_test.obs["cell_type"].to_list(), 
                                    "fold": [fold]*adata_test.obs['scNym'].shape[0]})
        results = pd.concat([results,dataframe_temp], axis=0)

# Reset index
results.reset_index(drop=True, inplace=True)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (6855, 14322)
# y:  (6855,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.010722877457737923
# running_acc  :  0.07421875
# corrects: 19.000000 | total: 256.000000
# train Loss : 0.0027
# train Acc : 0.8287
# TRAIN EPOCH corrects: 4601.000000 | total: 5552.000000
# val Loss : 0.0009
# val Acc : 0.9692
# VAL EPOCH corrects: 598.000000 | total: 617.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0007319571450352669
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9692
# TRAIN EPOCH corrects: 5381.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9789
# VAL EPOCH corrects: 604.000000 | total: 617.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.0004901457577943802
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9838
# TRAIN EPOCH corrects: 5462.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.00020911720639560372
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9903
# TRAIN EPOCH corrects: 5498.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.00019465768127702177
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9924
# TRAIN EPOCH corrects: 5510.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9806
# VAL EPOCH corrects: 605.000000 | total: 617.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  7.787858339725062e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9930
# TRAIN EPOCH corrects: 5513.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0002
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  7.35692010493949e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9946
# TRAIN EPOCH corrects: 5522.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0002
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  2.7106343623017892e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9942
# TRAIN EPOCH corrects: 5520.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  7.378850568784401e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9957
# TRAIN EPOCH corrects: 5528.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  3.2610929338261485e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9962
# TRAIN EPOCH corrects: 5531.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  5.123643859406002e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9966
# TRAIN EPOCH corrects: 5533.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  2.8002557883155532e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 5538.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  2.472080450388603e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 5537.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  7.340750744333491e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9986
# TRAIN EPOCH corrects: 5544.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  1.0029441000369843e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  3.044486220460385e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  1.7926549844560213e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  8.06702155387029e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  3.0274655728135258e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5545.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  9.924157893692609e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  2.2672893464914523e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  3.787167088376009e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  3.3353415346937254e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  8.886124305718113e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  6.1800237745046616e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  8.044819878705312e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  6.304663202172378e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  6.772002507204888e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  1.8509195797378197e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  6.2259332480607554e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  2.017601582338102e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  1.2986433830519672e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  4.252391590853222e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  6.221728199307108e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  1.1710329090419691e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  4.976366653863806e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  2.6723448172560893e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  4.582380825013388e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  6.004249371471815e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  8.767369763518218e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  3.1511365250480594e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 41/99
# ----------
# Iter :  0
# running_loss :  3.5340790418558754e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 42/99
# ----------
# Iter :  0
# running_loss :  7.673953405173961e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 43/99
# ----------
# Iter :  0
# running_loss :  3.4520592180342646e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 44/99
# ----------
# Iter :  0
# running_loss :  5.337294169294182e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 45/99
# ----------
# Iter :  0
# running_loss :  1.5043870007502846e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 46/99
# ----------
# Iter :  0
# running_loss :  4.552267000690335e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 47/99
# ----------
# Iter :  0
# running_loss :  1.4415791156352498e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 48/99
# ----------
# Iter :  0
# running_loss :  1.155760583060328e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 49/99
# ----------
# Iter :  0
# running_loss :  4.980224730388727e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 50/99
# ----------
# Iter :  0
# running_loss :  1.074590727512259e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 51/99
# ----------
# Iter :  0
# running_loss :  1.8065074982587248e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 52/99
# ----------
# Iter :  0
# running_loss :  2.391104544585687e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  5.116440206620609e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  9.300110264121031e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  2.486766334186541e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  1.23196252843627e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  3.111054866167251e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  2.743483491940424e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  2.744041694313637e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  1.6988672086881706e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  1.6057776974776061e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  1.686659743427299e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  3.477685822872445e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  1.4683815834359848e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  2.158708184651914e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  2.0494403543125372e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  3.517238383210497e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  3.858458512695506e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  1.6733821439629537e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  1.989165866689291e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  7.521070529037388e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  7.629560059285723e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  1.9268620690127136e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  4.02388968723244e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  4.212734893371817e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  1.9608382899605203e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  1.2000835340586491e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  2.0557406514853938e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  1.1727165656338912e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  2.77120852842927e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  1.4187389751896262e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  1.5945270206429996e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0007
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  1.6554716921746149e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  1.6170718026842223e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  1.8155286625187728e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  1.2154744126746664e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  2.1396626834757626e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  1.3108015082252678e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  2.0269567357900087e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  7.0303608481481206e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  4.0726094994170126e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  1.0015193083745544e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  1.5642114021829912e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  1.1866262639159686e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  2.7257246983936056e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  2.1929797640041215e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  1.2845833907704218e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  1.5823736703168834e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  3.535557880240958e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.0920771670838197
# EVAL ACC :  0.9912536443148688
# Predictions | Labels
# [[0 0]
#  [3 3]
#  [3 3]
#  [3 3]
#  [3 3]
#  [3 3]
#  [3 3]
#  [3 3]
#  [2 2]
#  [3 3]
#  [0 0]
#  [2 2]
#  [3 3]
#  [3 3]
#  [5 5]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 14 classes from 14322 features
# ['acinar' 'activated_stellate' 'alpha' 'beta' 'delta' 'ductal'
#  'endothelial' 'epsilon' 'gamma' 'macrophage' 'mast' 'quiescent_stellate'
#  'schwann' 't_cell']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 14.79it/s]
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Extracting model embeddings...
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (6855, 14322)
# y:  (6855,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.011080782860517502
# running_acc  :  0.05078125
# corrects: 13.000000 | total: 256.000000
# train Loss : 0.0028
# train Acc : 0.8242
# TRAIN EPOCH corrects: 4576.000000 | total: 5552.000000
# val Loss : 0.0009
# val Acc : 0.9433
# VAL EPOCH corrects: 582.000000 | total: 617.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0007139670196920633
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9678
# TRAIN EPOCH corrects: 5373.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9741
# VAL EPOCH corrects: 601.000000 | total: 617.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.00020221741579007357
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9856
# TRAIN EPOCH corrects: 5472.000000 | total: 5552.000000
# val Loss : 0.0008
# val Acc : 0.9643
# VAL EPOCH corrects: 595.000000 | total: 617.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.00015547234215773642
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9903
# TRAIN EPOCH corrects: 5498.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9757
# VAL EPOCH corrects: 602.000000 | total: 617.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.00013419367314781994
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9903
# TRAIN EPOCH corrects: 5498.000000 | total: 5552.000000
# val Loss : 0.0007
# val Acc : 0.9708
# VAL EPOCH corrects: 599.000000 | total: 617.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  6.39565332676284e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9926
# TRAIN EPOCH corrects: 5511.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0007
# val Acc : 0.9757
# VAL EPOCH corrects: 602.000000 | total: 617.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.0003014746471308172
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9933
# TRAIN EPOCH corrects: 5515.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0005
# val Acc : 0.9822
# VAL EPOCH corrects: 606.000000 | total: 617.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.00013357412535697222
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9953
# TRAIN EPOCH corrects: 5526.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9789
# VAL EPOCH corrects: 604.000000 | total: 617.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.00011263650958426297
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9948
# TRAIN EPOCH corrects: 5523.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0005
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  6.115760334068909e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9960
# TRAIN EPOCH corrects: 5530.000000 | total: 5552.000000
# val Loss : 0.0007
# val Acc : 0.9789
# VAL EPOCH corrects: 604.000000 | total: 617.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  2.303841210959945e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9966
# TRAIN EPOCH corrects: 5533.000000 | total: 5552.000000
# val Loss : 0.0007
# val Acc : 0.9757
# VAL EPOCH corrects: 602.000000 | total: 617.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  1.604759927431587e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5541.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9789
# VAL EPOCH corrects: 604.000000 | total: 617.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  2.501343442418147e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 5537.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  4.8735804739408195e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5541.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0004
# val Acc : 0.9806
# VAL EPOCH corrects: 605.000000 | total: 617.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  0.00010163945989916101
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9977
# TRAIN EPOCH corrects: 5539.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0003
# val Acc : 0.9822
# VAL EPOCH corrects: 606.000000 | total: 617.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  3.269150693085976e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5546.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  3.8978854718152434e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5543.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  2.9303595511009917e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9982
# TRAIN EPOCH corrects: 5542.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  1.3288720765558537e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5545.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9822
# VAL EPOCH corrects: 606.000000 | total: 617.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  3.164330337313004e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5545.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9822
# VAL EPOCH corrects: 606.000000 | total: 617.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  2.1562347683357075e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  6.495601155620534e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  2.216216444139718e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0009
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  1.7330210539512336e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9773
# VAL EPOCH corrects: 603.000000 | total: 617.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  7.0944943217909895e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  6.312152436294127e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5546.000000 | total: 5552.000000
# val Loss : 0.0009
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  3.531470792950131e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  1.598924063728191e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  1.541701567475684e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0007
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  3.7390452689578524e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  3.2660318538546562e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  2.5500860374449985e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  5.1699066716537345e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  7.885062586865388e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  7.363782515312778e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  8.981859537016135e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  5.667470304615563e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  1.5294683635147521e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0009
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  5.6560725170129444e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  3.357131618031417e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  9.524320375930984e-06
# ...
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 52/99
# ----------
# Iter :  0
# running_loss :  1.817198835851741e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  2.54459268944629e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5551.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  8.089160473900847e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5551.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  2.0312832020863425e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  3.289511823822977e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0004
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  1.1924845466637635e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0008
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  1.3800304259348195e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  7.2142061071645e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0009
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  2.109919705617358e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5551.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  2.5514161734463414e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  5.020765911467606e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  2.970883997477358e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  6.768959792680107e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  6.6702268668450415e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  2.963781071230187e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  1.9077290289715165e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0009
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  1.3643909824168077e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  3.4687539027800085e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  2.8148515411885455e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  1.7437901988159865e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  5.199693191570987e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  2.7171311103302287e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  9.49671448324807e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5551.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  4.922003881802084e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  4.57811694332122e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0008
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  1.2029354365949985e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0013
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  1.085493295249762e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  4.294446171115851e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0008
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  9.208297342411242e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  1.963267550308956e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0009
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  5.2415339268918615e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  3.2244845442619408e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  1.1027927939721849e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  1.2841176157962764e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  7.244593689392786e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  2.4189739633584395e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  3.6991243632655824e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0004
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  6.276345061451138e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0004
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  3.895615463989088e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5551.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  8.045547588153568e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0008
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  8.66526534082368e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0004
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  7.502586640839581e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  7.204726557574759e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0009
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  1.3598984878626652e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0009
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  1.585301902196079e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0004
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  1.5346423651863006e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  2.220348960690899e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  2.756848061835626e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.07527767277012269
# EVAL ACC :  0.9883381924198251
# Predictions | Labels
# [[0 0]
#  [2 2]
#  [1 1]
#  [3 3]
#  [3 3]
#  [3 3]
#  [4 4]
#  [5 5]
#  [3 3]
#  [3 3]
#  [3 3]
#  [2 2]
#  [8 8]
#  [3 3]
#  [2 2]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 14 classes from 14322 features
# ['acinar' 'activated_stellate' 'alpha' 'beta' 'delta' 'ductal'
#  'endothelial' 'epsilon' 'gamma' 'macrophage' 'mast' 'quiescent_stellate'
#  'schwann' 't_cell']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 12.42it/s]
# Extracting model embeddings...

# %%
# Save results
results.to_csv('results/scNym_output.csv', index=True)

# %%
# Extract the unique labels
unique_labels1 = np.unique(results.true_label)
unique_labels2 = np.unique(results.pred)
unique_labels = np.unique(np.concatenate([unique_labels1,unique_labels2]))

# Convert string labels to numerical labels
label_encoder_temp = LabelEncoder()
label_encoder_temp.fit(unique_labels)
y_true = label_encoder_temp.transform(results.true_label)
y_pred = label_encoder_temp.transform(results.pred)

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9883300268409383
