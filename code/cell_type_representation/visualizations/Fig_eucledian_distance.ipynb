# %% [markdown]
# #### Calculates the average min-max normalized Euclidean distance between cell types within each patients data. Also calculate CV score

# %%
# Import packages
from functions.Eucledian_distance_visualization_functions import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %%
VisEnv.ReadscData(path="../../../data/processed/merged/merged_all.h5ad",
                target_key="cell_type",
                batch_key="patientID")

# %%
VisEnv.CalculateDistanceMatrix()
# Out:
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\env\lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\env\lib\site-packages\numpy\core\_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\env\lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\env\lib\site-packages\numpy\core\_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\env\lib\site-packages\numpy\core\_methods.py:226: RuntimeWarning: invalid value encountered in divide
# ...

# %% [markdown]
# ### Visualize results

# %%
VisEnv.VisCellTypeCorrelations(image_path="figures/CellTypeCentroidDistance")
# Out:
# mean CV value:  tensor(0.1064)
# std CV value:  tensor(0.0761)
# Number fo cell types:  46
