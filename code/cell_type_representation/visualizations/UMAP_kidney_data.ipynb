# %% [markdown]
# ### Code for visualizing PCA and CELLULAR embedding space of the first fold of the kidney dataset

# %%
# Import packages
from functions.UMAP_viz_fun import UMAP_Kidney_Viz as UKV

# %%
# Initiate env
env = UKV(data_path="../../../data/processed/kidney_cells/Muto_merged.h5ad",
          fold=1)

# %%
# Make figure
env.umap_viz(save_path="trained_models/Assess_generalisability/Kidney/Model1/",
             image_path="figures/kidney_dataset_model1_comp_pca")
# Out:
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\env\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_representation\visualizations\functions\UMAP_viz_fun.py:185: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   vis_adata.obs["cell_type_encoded"] = le_cell_type.fit_transform(vis_adata.obs["cell_type"])
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\env\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# ...
