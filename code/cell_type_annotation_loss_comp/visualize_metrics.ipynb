# %% [markdown]
# ### Visualizations for comparing the use of different loss functions for CELLULAR. Both cell type annotation and cell type embedding space benchmarks were performed

# %%
# Import packages
from visualize_metrics import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %%
file = "results_and_visualizations/results_benchmark"
VisEnv.read_csv(file=file)

# %% [markdown]
# ### Cell type annotation benchmark

# %%
image_path = "figures/Loss_comp_metrics"
VisEnv.LossCompBoxPlotVisualization(image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_annotation_loss_comp\visualize_metrics.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "CELLULAR CL + Centroid Loss"] = "CELLULAR | Centroid + CL Loss"
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_annotation_loss_comp\visualize_metrics.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "CELLULAR CL Loss"] = "CELLULAR | CL Loss"
# ...

# %% [markdown]
# ### Latent space benchmark

# %% [markdown]
# The overall score is calculated based on metrics from the paper by [Luecken, et al.](https://www.nature.com/articles/s41592-021-01336-8#Sec10)

# %%
files = ["train_code/benchmark_results/Segerstolpe/Benchmark_representation_results",
         "train_code/benchmark_results/MacParland/Benchmark_representation_results",
         "train_code/benchmark_results/Baron/Benchmark_representation_results"]
dataset_names = ["Segerstolpe",
                 "MacParland",
                 "Baron"]
image_path = "figures/Loss_comp__latent_space_metrics"
VisEnv.BoxPlotVisualization(files=files, dataset_names=dataset_names, image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_annotation_loss_comp\visualize_metrics.py:224: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "CELLULAR CL + Centroid Loss"] = "CELLULAR | Centroid + CL Loss"
# c:\Users\user\Documents\GitHub\CELLULAR_reproducibility\code\cell_type_annotation_loss_comp\visualize_metrics.py:225: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "CELLULAR CL Loss"] = "CELLULAR | CL Loss"
# ...
